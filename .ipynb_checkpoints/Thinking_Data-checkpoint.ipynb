# %%
import json

# %%
def load_Data(filename):
    with open(filename,"r"):
        Data=json.load(r)
        return Data

# %%
load_Data("Data.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 load_Data("Data.json")
#
# Cell In[2], line 3, in load_Data(filename)
#       1 def load_Data(filename):
#       2     with open(filename,"r"):
# ----> 3         Data=json.load(r)
#       4         return Data
#
# NameError: name 'r' is not defined
